# %% [markdown]
# # TPC1: Análise de dados: doença cardíaca
#
# Descarregue o ficheiro de dados: `myheart.csv`
# Crie um programa em Python, conjunto de funções, que responda às seguintes questões:
# * Crie uma função que lê a informação do ficheiro para um modelo, previamente pensado em memória;
# * Pense num modelo para guardar uma distribuição;
# * Crie uma função que calcula a distribuição da doença por sexo;
# * Crie uma função que calcula a distribuição da doença por escalões etários. Considere os seguintes escalões: [30-34], [35-39], [40-44], ...
# * Crie uma função que calcula a distribuição da doença por níveis de colesterol. Considere um nível igual a um intervalo de 10 unidades, comece no limite inferior e crie os níveis necessários até abranger o limite superior;
# * Crie uma função que imprime na forma de uma tabela uma distribuição;
# * Especifique um programa que ao executar apresenta as tabelas correspondentes às distribuições pedidas;
# * Extra: explore o módulo matplotlib e crie gráficos para as suas distribuições.

# %% [markdown]
# # Exercício 1

# %%
# idade,sexo,tensão,colesterol,batimento,temDoenças

def readfile():
  model = dict()
  
  headers = ["age", "gender", "blood_pressure", "cholesterol", "bpm","is_sick"]
  idx = 0
  file = open("myheart.csv")
  for line in file.readlines():
    if idx != 0:
      myheart = dict()
      for i in range(0,len(headers)):
        myheart[headers[i]] = line.strip().split(',')[i]
      model[idx-1] = myheart
    idx+=1
  return model

print(readfile())
# Out:
# {0: {'age': '40', 'gender': 'M', 'blood_pressure': '140', 'cholesterol': '289', 'bpm': '172', 'is_sick': '0'}, 1: {'age': '49', 'gender': 'F', 'blood_pressure': '160', 'cholesterol': '180', 'bpm': '156', 'is_sick': '1'}, 2: {'age': '37', 'gender': 'M', 'blood_pressure': '130', 'cholesterol': '283', 'bpm': '98', 'is_sick': '0'}, 3: {'age': '48', 'gender': 'F', 'blood_pressure': '138', 'cholesterol': '214', 'bpm': '108', 'is_sick': '1'}, 4: {'age': '54', 'gender': 'M', 'blood_pressure': '150', 'cholesterol': '195', 'bpm': '122', 'is_sick': '0'}, 5: {'age': '39', 'gender': 'M', 'blood_pressure': '120', 'cholesterol': '339', 'bpm': '170', 'is_sick': '0'}, 6: {'age': '45', 'gender': 'F', 'blood_pressure': '130', 'cholesterol': '237', 'bpm': '170', 'is_sick': '0'}, 7: {'age': '54', 'gender': 'M', 'blood_pressure': '110', 'cholesterol': '208', 'bpm': '142', 'is_sick': '0'}, 8: {'age': '37', 'gender': 'M', 'blood_pressure': '140', 'cholesterol': '207', 'bpm': '130', 'is_sick': '1'}, 9: {'age': '48', 'gender': 'F', 'blood_pressure': '120', 'cholesterol': '284', 'bpm': '120', 'is_sick': '0'}, 10: {'age': '37', 'gender': 'F', 'blood_pressure': '130', 'cholesterol': '211', 'bpm': '142', 'is_sick': '0'}, 11: {'age': '58', 'gender': 'M', 'blood_pressure': '136', 'cholesterol': '164', 'bpm': '99', 'is_sick': '1'}, 12: {'age': '39', 'gender': 'M', 'blood_pressure': '120', 'cholesterol': '204', 'bpm': '145', 'is_sick': '0'}, 13: {'age': '49', 'gender': 'M', 'blood_pressure': '140', 'cholesterol': '234', 'bpm': '140', 'is_sick': '1'}, 14: {'age': '42', 'gender': 'F', 'blood_pressure': '115', 'cholesterol': '211', 'bpm': '137', 'is_sick': '0'}, 15: {'age': '54', 'gender': 'F', 'blood_pressure': '120', 'cholesterol': '273', 'bpm': '150', 'is_sick': '0'}, 16: {'age': '38', 'gender': 'M', 'blood_pressure': '110', 'cholesterol': '196', 'bpm': '166', 'is_sick': '1'}, 17: {'age': '43', 'gender': 'F', 'blood_pressure': '120', 'cholesterol': '201', 'bpm': '165', 'is_sick': '0'}, 18: {'age': '60', 'gender': 'M', 'blood_pressure': '100', 'cholesterol': '248', 'bpm': '125', 'is_sick': '1'}, 19: {'age': '36', 'gender': 'M', 'blood_pressure': '120', 'cholesterol': '267', 'bpm': '160', 'is_sick': '1'}, 20: {'age': '43', 'gender': 'F', 'blood_pressure': '100', 'cholesterol': '223', 'bpm': '142', 'is_sick': '0'}, 21: {'age': '44', 'gender': 'M', 'blood_pressure': '120', 'cholesterol': '184', 'bpm': '142', 'is_sick': '0'}, 22: {'age': '49', 'gender': 'F', 'blood_pressure': '124', 'cholesterol': '201', 'bpm': '164', 'is_sick': '0'}, 23: {'age': '44', 'gender': 'M', 'blood_pressure': '150', 'cholesterol': '288', 'bpm': '150', 'is_sick': '1'}, 24: {'age': '40', 'gender': 'M', 'blood_pressure': '130', 'cholesterol': '215', 'bpm': '138', 'is_sick': '0'}, 25: {'age': '36', 'gender': 'M', 'blood_pressure': '130', 'cholesterol': '209', 'bpm': '178', 'is_sick': '0'}, 26: {'age': '53', 'gender': 'M', 'blood_pressure': '124', 'cholesterol': '260', 'bpm': '112', 'is_sick': '0'}, 27: {'age': '52', 'gender': 'M', 'blood_pressure': '120', 'cholesterol': '284', 'bpm': '118', 'is_sick': '0'}, 28: {'age': '53', 'gender': 'F', 'blood_pressure': '113', 'cholesterol': '468', 'bpm': '127', 'is_sick': '0'}, 29: {'age': '51', 'gender': 'M', 'blood_pressure': '125', 'cholesterol': '188', 'bpm': '145', 'is_sick': '0'}, 30: {'age': '53', 'gender': 'M', 'blood_pressure': '145', 'cholesterol': '518', 'bpm': '130', 'is_sick': '1'}, 31: {'age': '56', 'gender': 'M', 'blood_pressure': '130', 'cholesterol': '167', 'bpm': '114', 'is_sick': '0'}, 32: {'age': '54', 'gender': 'M', 'blood_pressure': '125', 'cholesterol': '224', 'bpm': '122', 'is_sick': '1'}, 33: {'age': '41', 'gender': 'M', 'blood_pressure': '130', 'cholesterol': '172', 'bpm': '130', 'is_sick': '1'}, 34: {'age': '43', 'gender': 'F', 'blood_pressure': '150', 'cholesterol': '186', 'bpm': '154', 'is_sick': '0'}, 35: {'age': '32', 'gender': 'M', 'blood_pressure': '125', 'cholesterol': '254', 'bpm': '155', 'is_sick': '0'}, 36: {'age': '65 ...

# %% [markdown]
# # Exercício 2

# %%
def distribution_by_bpm():
    model = readfile()
    bpm = dict()
    for values in model.values():
        if int(values["bpm"]) not in bpm.keys():
            bpm[int(values["bpm"])] = 1
        else:
            bpm[int(values["bpm"])] = bpm.get(int(values["bpm"]))+1
    
    return dict(sorted(bpm.items()))

print(distribution_by_bpm())
# Out:
# {60: 1, 63: 1, 67: 1, 69: 1, 70: 1, 71: 1, 72: 2, 73: 1, 77: 1, 78: 1, 80: 2, 82: 3, 83: 1, 84: 3, 86: 4, 87: 1, 88: 2, 90: 2, 91: 1, 92: 6, 93: 2, 94: 4, 95: 2, 96: 7, 97: 2, 98: 9, 99: 7, 100: 14, 102: 4, 103: 4, 104: 2, 105: 11, 106: 5, 107: 1, 108: 7, 109: 5, 110: 23, 111: 5, 112: 13, 113: 4, 114: 6, 115: 14, 116: 9, 117: 6, 118: 12, 119: 5, 120: 35, 121: 5, 122: 20, 123: 5, 124: 9, 125: 21, 126: 12, 127: 8, 128: 14, 129: 4, 130: 32, 131: 6, 132: 7, 133: 5, 134: 6, 135: 15, 136: 4, 137: 6, 138: 14, 139: 6, 140: 39, 141: 5, 142: 12, 143: 7, 144: 9, 145: 13, 146: 3, 147: 5, 148: 9, 149: 6, 150: 41, 151: 5, 152: 9, 153: 3, 154: 12, 155: 12, 156: 8, 157: 6, 158: 6, 159: 5, 160: 22, 161: 5, 162: 9, 163: 9, 164: 3, 165: 11, 166: 4, 167: 2, 168: 7, 169: 4, 170: 20, 171: 2, 172: 8, 173: 5, 174: 5, 175: 10, 176: 2, 177: 1, 178: 6, 179: 5, 180: 10, 181: 2, 182: 3, 184: 4, 185: 3, 186: 2, 187: 1, 188: 1, 190: 1, 192: 1, 194: 1, 195: 1, 202: 1}

# %% [markdown]
# # Exercício 3

# %%
def total_by_gender():
    model = readfile()
    total = dict()
    total['M'] = 0
    total['F'] = 0
    for values in model.values():
        total[values["gender"]] = total.get(values["gender"]) + 1
    
    return total

def total():
    return len(readfile().values())

def distribution_by_gender():
    model = readfile()
    sick = dict()
    sick['M'] = 0
    sick['F'] = 0 
    for values in model.values():
        if int(values["is_sick"]) == 1:
            sick[values["gender"]] = sick.get(values["gender"]) + 1

    return sick


res = distribution_by_gender()
total_doente_m = int(res['M'])
total_doente_f = int(res['F'])
total_gender = total_by_gender()
print(distribution_by_gender())
print(f"doentes masculino: {res['M']} / {total_gender['M']}")
print(f"doentes feminino: {res['F']} / {total_gender['F']}")
print(f"doentes: {total_doente_m + total_doente_f} / {total()} ")
# Out:
# {'M': 428, 'F': 40}
# doentes masculino: 428 / 670
# doentes feminino: 40 / 169
# doentes: 468 / 839

# %% [markdown]
# # Exercício 4

# %%
# 0 - 4 5 - 9
def distribution_by_age_group():
    model = readfile()
    age_group = dict()
    for values in model.values():
        lower_bound = int(values["age"]) - (int(values["age"]) % 5)
        upper_bound = lower_bound + 4
        k = str(lower_bound) + "-" + str(upper_bound)
        if k not in age_group.keys():
            age_group[k] = 1 
        else:
            age_group[k] = age_group.get(k) + 1
                
    return dict(sorted(age_group.items()))

print(distribution_by_age_group())
# Out:
# {'25-29': 4, '30-34': 17, '35-39': 53, '40-44': 88, '45-49': 107, '50-54': 168, '55-59': 172, '60-64': 135, '65-69': 65, '70-74': 23, '75-79': 7}

# %% [markdown]
# # Exercício 5

# %%
def distribution_by_colesterol():
    colesterol = dict()
    for values in readfile().values():
        k = int(values["cholesterol"])
        if k not in colesterol.keys() and k != 0:
            colesterol[k] = 1
        else:
            if k != 0:
                colesterol[k] = colesterol.get(k) + 1
    return dict(sorted(colesterol.items()))

print(distribution_by_colesterol())
# Out:
# {85: 1, 100: 2, 110: 1, 113: 1, 117: 1, 123: 1, 126: 2, 129: 1, 132: 1, 139: 2, 141: 1, 142: 1, 147: 2, 149: 2, 152: 1, 153: 1, 156: 1, 159: 1, 160: 6, 161: 2, 163: 2, 164: 1, 165: 1, 166: 4, 167: 3, 168: 2, 169: 1, 170: 2, 171: 3, 172: 2, 173: 2, 174: 1, 175: 2, 177: 5, 178: 1, 179: 2, 180: 3, 181: 2, 182: 5, 184: 4, 185: 2, 186: 5, 187: 1, 188: 3, 190: 2, 192: 2, 193: 5, 194: 2, 195: 7, 196: 6, 197: 5, 198: 6, 199: 2, 200: 4, 201: 6, 202: 3, 203: 5, 204: 7, 205: 2, 206: 2, 207: 6, 208: 7, 209: 5, 210: 4, 211: 9, 212: 4, 213: 7, 214: 7, 215: 6, 216: 8, 217: 4, 218: 6, 219: 6, 220: 8, 221: 4, 222: 6, 223: 9, 224: 6, 225: 6, 226: 6, 227: 3, 228: 5, 229: 3, 230: 9, 231: 4, 232: 2, 233: 6, 234: 6, 235: 5, 236: 5, 237: 6, 238: 4, 239: 4, 240: 7, 241: 3, 242: 2, 243: 6, 244: 4, 245: 6, 246: 8, 247: 1, 248: 5, 249: 5, 250: 5, 251: 1, 252: 3, 253: 2, 254: 11, 255: 2, 256: 5, 257: 2, 258: 7, 259: 2, 260: 7, 261: 3, 262: 1, 263: 6, 264: 4, 265: 4, 266: 3, 267: 5, 268: 4, 269: 5, 270: 6, 271: 4, 272: 3, 273: 5, 274: 5, 275: 7, 276: 4, 277: 5, 279: 1, 280: 2, 281: 3, 282: 6, 283: 4, 284: 3, 285: 2, 286: 1, 287: 2, 288: 6, 289: 6, 290: 1, 291: 3, 292: 4, 293: 1, 294: 3, 295: 5, 297: 4, 298: 5, 299: 2, 300: 2, 302: 1, 303: 4, 304: 2, 305: 4, 306: 3, 307: 1, 308: 5, 309: 4, 310: 3, 311: 2, 312: 2, 313: 1, 315: 3, 316: 1, 318: 2, 319: 1, 320: 2, 322: 1, 325: 1, 326: 2, 327: 1, 328: 1, 329: 1, 330: 2, 331: 1, 333: 1, 336: 1, 337: 1, 338: 1, 339: 2, 340: 1, 341: 2, 342: 2, 344: 1, 347: 1, 349: 1, 354: 1, 355: 1, 358: 1, 360: 1, 365: 1, 369: 1, 384: 1, 385: 1, 388: 1, 392: 1, 393: 1, 394: 2, 404: 1, 407: 1, 409: 1, 412: 1, 417: 1, 458: 1, 466: 1, 468: 1, 491: 1, 518: 1, 529: 1, 564: 1, 603: 1}

# %% [markdown]
# # Exercício 6

# %%
def replicate(c:str,n:int):
    res = str()
    for _ in range(0,n):
        res = res + c
    return res

def distribution_to_table(distribution:dict):
    print("---------------")
    spaces = str()
    spaces_out = str()
    for k in distribution.keys():
        match len(str(k)):
            case 1:
                spaces = replicate(" ", 2)
            case 2:
                spaces = " "
            case _:
                spaces = ""
        
        match len(str(distribution.get(k))):
            case 1:
                spaces_out = replicate(" ", 5)
            case 2:
                spaces_out = replicate(" ", 4)
            case 3:
                spaces_out = replicate(" ", 3)
            case _:
                spaces_out = replicate(" ", 2)
        
        spaces_out = spaces_out + '|'
        
        print(f"|{str(k)} {spaces}| {str(distribution[k])} {spaces_out}")
        print("---------------")
    
distribution_to_table(distribution_by_gender())
# Out:
# ---------------
# |M   | 428    |
# ---------------
# |F   | 40     |
# ---------------

# %% [markdown]
# # Exercício 7

# %%
def distributions_to_table():
    print(distribution_to_table(distribution_by_bpm()))
    print(distribution_to_table(distribution_by_gender()))
    print(distribution_to_table(distribution_by_age_group()))
    print(distribution_to_table(distribution_by_colesterol()))

print(distributions_to_table())
# Out:
# ---------------
# |60  | 1      |
# ---------------
# |63  | 1      |
# ---------------
# |67  | 1      |
# ---------------
# |69  | 1      |
# ---------------
# |70  | 1      |
# ---------------
# |71  | 1      |
# ---------------
# |72  | 2      |
# ---------------
# |73  | 1      |
# ---------------
# |77  | 1      |
# ---------------
# |78  | 1      |
# ---------------
# |80  | 2      |
# ---------------
# |82  | 3      |
# ---------------
# |83  | 1      |
# ---------------
# |84  | 3      |
# ---------------
# |86  | 4      |
# ---------------
# |87  | 1      |
# ---------------
# |88  | 2      |
# ---------------
# |90  | 2      |
# ---------------
# |91  | 1      |
# ---------------
# |92  | 6      |
# ---------------
# |93  | 2      |
# ---------------
# |94  | 4      |
# ---------------
# |95  | 2      |
# ---------------
# |96  | 7      |
# ---------------
# |97  | 2      |
# ---------------
# |98  | 9      |
# ---------------
# |99  | 7      |
# ---------------
# |100 | 14     |
# ---------------
# |102 | 4      |
# ---------------
# |103 | 4      |
# ---------------
# |104 | 2      |
# ---------------
# |105 | 11     |
# ---------------
# |106 | 5      |
# ---------------
# |107 | 1      |
# ---------------
# |108 | 7      |
# ---------------
# |109 | 5      |
# ---------------
# |110 | 23     |
# ---------------
# |111 | 5      |
# ---------------
# |112 | 13     |
# ---------------
# |113 | 4      |
# ---------------
# |114 | 6      |
# ---------------
# |115 | 14     |
# ---------------
# |116 | 9      |
# ---------------
# |117 | 6      |
# ---------------
# |118 | 12     |
# ---------------
# |119 | 5      |
# ---------------
# |120 | 35     |
# ---------------
# |121 | 5      |
# ---------------
# |122 | 20     |
# ---------------
# |123 | 5      |
# ---------------
# |124 | 9      |
# ---------------
# |125 | 21     |
# ---------------
# |126 | 12     |
# ---------------
# |127 | 8      |
# ---------------
# |128 | 14     |
# ---------------
# |129 | 4      |
# ---------------
# |130 | 32     |
# ---------------
# |131 | 6      |
# ---------------
# |132 | 7      |
# ---------------
# |133 | 5      |
# ---------------
# |134 | 6      |
# ---------------
# |135 | 15     |
# ---------------
# |136 | 4      |
# ---------------
# |137 | 6      |
# ---------------
# |138 | 14     |
# ---------------
# |139 | 6      |
# ---------------
# |140 | 39     |
# ---------------
# |141 | 5      |
# ---------------
# |142 | 12     |
# ---------------
# |143 | 7      |
# ---------------
# |144 | 9      |
# ---------------
# |145 | 13     |
# ---------------
# |146 | 3      |
# ---------------
# |147 | 5      |
# ---------------
# |148 | 9      |
# ---------------
# |149 | 6      |
# ---------------
# |150 | 41     |
# ---------------
# |151 | 5      |
# ---------------
# |152 | 9      |
# ---------------
# |153 | 3      |
# ---------------
# |154 | 12     |
# ---------------
# |155 | 12     |
# ---------------
# |156 | 8      |
# ---------------
# |157 | 6      |
# ---------------
# |158 | 6      |
# ---------------
# |159 | 5      |
# ---------------
# |160 | 22     |
# ---------------
# |161 | 5      |
# ---------------
# |162 | 9      |
# ---------------
# |163 | 9      |
# ---------------
# |164 | 3      |
# ---------------
# |165 | 11     |
# ---------------
# |166 | 4      |
# ---------------
# |167 | 2      |
# ---------------
# |168 | 7      |
# ---------------
# |169 | 4      |
# ---------------
# |170 | 20     |
# ---------------
# |171 | 2      |
# ---------------
# |172 | 8      |
# ---------------
# |173 | 5      |
# ---------------
# |174 | 5      |
# ---------------
# |175 | 10     |
# ---------------
# |176 | 2      |
# ---------------
# |177 | 1      |
# ---------------
# |178 | 6      |
# ---------------
# |179 | 5      |
# ---------------
# |180 | 10     |
# ---------------
# |181 | 2      |
# ---------------
# |182 | 3      |
# ---------------
# |184 | 4      |
# ---------------
# |185 | 3      |
# ---------------
# |186 | 2      |
# ---------------
# |187 | 1      |
# ---------------
# |188 | 1      |
# ---------------
# |190 | 1      |
# ---------------
# |192 | 1      |
# ---------------
# |194 | 1      |
# ---------------
# |195 | 1      |
# ---------------
# |202 | 1      |
# ---------------
# None
# ---------------
# |M   | 428    |
# ---------------
# |F   | 40     |
# ---------------
# None
# ---------------
# |25-29 | 4      |
# ---------------
# |30-34 | 17     |
# ---------------
# |35-39 | 53     |
# ---------------
# |40-44 | 88     |
# ---------------
# |45-49 | 107    |
# ---------------
# |50-54 | 168    |
# ---------------
# |55-59 | 172    |
# ---------------
# |60-64 | 135    |
# ---------------
# |65-69 | 65     |
# ---------------
# |70-74 | 23     |
# ---------------
# |75-79 | 7      |
# ---------------
# None
# ---------------
# |85  | 1      |
# ---------------
# |100 | 2      |
# ---------------
# |110 | 1      |
# ---------------
# |113 | 1      |
# ---------------
# |117 | 1      |
# ---------------
# |123 | 1      |
# ---------------
# |126 | 2      |
# ---------------
# |129 | 1      |
# ---------------
# |132 | 1      |
# ---------------
# |139 | 2      |
# ---------------
# |141 | 1      |
# ---------------
# |142 | 1      |
# ---------------
# |147 | 2      |
# ---------------
# |149 | 2      |
# ---------------
# |152 | 1      |
# ---------------
# |153 | 1      |
# ---------------
# |156 | 1      |
# ---------------
# |159 | 1      |
# ---------------
# |160 | 6      |
# ---------------
# |161 | 2      |
# ---------------
# |163 | 2      |
# ---------------
# |164 | 1      |
# ---------------
# |165 | 1      |
# ---------------
# |166 | 4      |
# ---------------
# |167 | 3      |
# ---------------
# |168 | 2      |
# ---------------
# |169 | 1      |
# ---------------
# |170 | 2      |
# ---------------
# |171 | 3      |
# ---------------
# |172 | 2      |
# ---------------
# |173 | 2      |
# ---------------
# |174 | 1      |
# ---------------
# |175 | 2      |
# ---------------
# |177 | 5      |
# ---------------
# |178 | 1      |
# ---------------
# |179 | 2      |
# ---------------
# |180 | 3      |
# ---------------
# |181 | 2      |
# ---------------
# |182 | 5      |
# ---------------
# |184 | 4      |
# ---------------
# |185 | 2      |
# ---------------
# |186 | 5      |
# ---------------
# |187 | 1      |
# ---------------
# |188 | 3      |
# ---------------
# |190 | 2      |
# ---------------
# |192 | 2      |
# ---------------
# |193 | 5      |
# ---------------
# |194 | 2      |
# ---------------
# |195 | 7      |
# ---------------
# |196 | 6      |
# ---------------
# |197 | 5      |
# ---------------
# |198 | 6      |
# ---------------
# |199 | 2      |
# ---------------
# |200 | 4      |
# ---------------
# |201 | 6      |
# ---------------
# |202 | 3      |
# ---------------
# |203 | 5      |
# ---------------
# |204 | 7      |
# ---------------
# |205 | 2      |
# ---------------
# |206 | 2      |
# ---------------
# |207 | 6      |
# ---------------
# |208 | 7      |
# ---------------
# |209 | 5      |
# ---------------
# |210 | 4      |
# ---------------
# |211 | 9      |
# ---------------
# |212 | 4      |
# ---------------
# |213 | 7      |
# ---------------
# |214 | 7      |
# ---------------
# |215 | 6      |
# ---------------
# |216 | 8      |
# ---------------
# |217 | 4      |
# ---------------
# |218 | 6      |
# ---------------
# |219 | 6      |
# ---------------
# |220 | 8      |
# ---------------
# |221 | 4      |
# ---------------
# |222 | 6      |
# ---------------
# |223 | 9      |
# ---------------
# |224 | 6      |
# ---------------
# |225 | 6      |
# ---------------
# |226 | 6      |
# ---------------
# |227 | 3      |
# ---------------
# |228 | 5      |
# ---------------
# |229 | 3      |
# ---------------
# |230 | 9      |
# ---------------
# |231 | 4      |
# ---------------
# |232 | 2      |
# ---------------
# |233 | 6      |
# ---------------
# |234 | 6      |
# ---------------
# |235 | 5      |
# ---------------
# |236 | 5      |
# ---------------
# |237 | 6      |
# ---------------
# |238 | 4      |
# ---------------
# |239 | 4      |
# ---------------
# |240 | 7      |
# ---------------
# |241 | 3      |
# ---------------
# |242 | 2      |
# ---------------
# |243 | 6      |
# ---------------
# |244 | 4      |
# ---------------
# |245 | 6      |
# ---------------
# |246 | 8      |
# ---------------
# |247 | 1      |
# ---------------
# |248 | 5      |
# ---------------
# |249 | 5      |
# ---------------
# |250 | 5      |
# ---------------
# |251 | 1      |
# ---------------
# |252 | 3      |
# ---------------
# |253 | 2      |
# ---------------
# |254 | 11     |
# ---------------
# |255 | 2      |
# ---------------
# |256 | 5      |
# ---------------
# |257 | 2      |
# ---------------
# |258 | 7      |
# ---------------
# |259 | 2      |
# ---------------
# |260 | 7      |
# ---------------
# |261 | 3      |
# ---------------
# |262 | 1      |
# ---------------
# |263 | 6      |
# ---------------
# |264 | 4      |
# ---------------
# |265 | 4      |
# ---------------
# |266 | 3      |
# ---------------
# |267 | 5      |
# ---------------
# |268 | 4      |
# ---------------
# |269 | 5      |
# ---------------
# |270 | 6      |
# ---------------
# |271 | 4      |
# ---------------
# |272 | 3      |
# ---------------
# |273 | 5      |
# ---------------
# |274 | 5      |
# ---------------
# |275 | 7      |
# ---------------
# |276 | 4      |
# ---------------
# |277 | 5      |
# ---------------
# |279 | 1      |
# ---------------
# |280 | 2      |
# ---------------
# |281 | 3      |
# ---------------
# |282 | 6      |
# ---------------
# |283 | 4      |
# ---------------
# |284 | 3      |
# ---------------
# |285 | 2      |
# ---------------
# |286 | 1      |
# ---------------
# |287 | 2      |
# ---------------
# |288 | 6      |
# ---------------
# |289 | 6      |
# ---------------
# |290 | 1      |
# ---------------
# |291 | 3      |
# ---------------
# |292 | 4      |
# ---------------
# |293 | 1      |
# ---------------
# |294 | 3      |
# ---------------
# |295 | 5      |
# ---------------
# |297 | 4      |
# ---------------
# |298 | 5      |
# ---------------
# |299 | 2      |
# ---------------
# |300 | 2      |
# ---------------
# |302 | 1      |
# ---------------
# |303 | 4      |
# ---------------
# |304 | 2      |
# ---------------
# |305 | 4      |
# ---------------
# |306 | 3      |
# ---------------
# |307 | 1      |
# ---------------
# |308 | 5      |
# ---------------
# |309 | 4      |
# ---------------
# |310 | 3      |
# ---------------
# |311 | 2      |
# ---------------
# |312 | 2      |
# ---------------
# |313 | 1      |
# ---------------
# |315 | 3      |
# ---------------
# |316 | 1      |
# ---------------
# |318 | 2      |
# ---------------
# |319 | 1      |
# ---------------
# |320 | 2      |
# ---------------
# |322 | 1      |
# ---------------
# |325 | 1      |
# ---------------
# |326 | 2      |
# ---------------
# |327 | 1      |
# ---------------
# |328 | 1      |
# ---------------
# |329 | 1      |
# ---------------
# |330 | 2      |
# ---------------
# |331 | 1      |
# ---------------
# |333 | 1      |
# ---------------
# |336 | 1      |
# ---------------
# |337 | 1      |
# ---------------
# |338 | 1      |
# ---------------
# |339 | 2      |
# ---------------
# |340 | 1      |
# ---------------
# |341 | 2      |
# ---------------
# |342 | 2      |
# ---------------
# |344 | 1      |
# ---------------
# |347 | 1      |
# ---------------
# |349 | 1      |
# ---------------
# |354 | 1      |
# ---------------
# |355 | 1      |
# ---------------
# |358 | 1      |
# ---------------
# |360 | 1      |
# ---------------
# |365 | 1      |
# ---------------
# |369 | 1      |
# ---------------
# |384 | 1      |
# ---------------
# |385 | 1      |
# ---------------
# |388 | 1      |
# ---------------
# |392 | 1      |
# ---------------
# |393 | 1      |
# ---------------
# |394 | 2      |
# ---------------
# |404 | 1      |
# ---------------
# |407 | 1      |
# ---------------
# |409 | 1      |
# ---------------
# |412 | 1      |
# ---------------
# |417 | 1      |
# ---------------
# |458 | 1      |
# ---------------
# |466 | 1      |
# ---------------
# |468 | 1      |
# ---------------
# |491 | 1      |
# ---------------
# |518 | 1      |
# ---------------
# |529 | 1      |
# ---------------
# |564 | 1      |
# ---------------
# |603 | 1      |
# ---------------
# None
# None

# %% [markdown]
# # Exercício 8

# %%
import matplotlib.pyplot as plt;

def distribution_graph():
    bpm = distribution_by_bpm()
    gender = distribution_by_gender()
    total_gender = total_by_gender()
    age_group = distribution_by_age_group()
    colesterol = distribution_by_colesterol()
    
    _, ax = plt.subplots()
    ax.bar(bpm.keys(), bpm.values())
    ax.set_title('distribuição por bpm')
    ax.set_xlabel("batimentos p/minuto")
    ax.set_ylabel('cardinalidade')
    plt.show()
    
    _, bx = plt.subplots()
    bx.bar(total_gender.keys(),total_gender.values())
    bx.bar(gender.keys(), gender.values())
    bx.set_title('distribuição por género')
    bx.set_xlabel("sexo")
    bx.set_ylabel('cardinalidade')
    plt.show()

    _, cx = plt.subplots()
    cx.bar(age_group.keys(), age_group.values())
    cx.set_title('distribuição por faixa etária')
    cx.set_xlabel("faixa etária")
    cx.set_ylabel('cardinalidade')
    plt.show()

    _, dx = plt.subplots()
    dx.bar(colesterol.keys(), colesterol.values())
    dx.set_title('distribuição por colesterol')
    dx.set_xlabel("colesterol")
    dx.set_ylabel('cardinalidade')

    plt.show()
    
distribution_graph()
